# %%
#clone repository
! git clone https://deepl_22_final_project_username:tVyAPPDFRAZFLsWEathG@gitup.uni-potsdam.de/macphail/deepl_final_project.git
# Out:
# Cloning into 'deepl_final_project'...
# remote: Enumerating objects: 415, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 415 (delta 57), reused 57 (delta 45), pack-reused 339
# Receiving objects: 100% (415/415), 7.80 MiB | 5.09 MiB/s, done.
# Resolving deltas: 100% (281/281), done.

# %%
#change directory 
# %cd /content/deepl_final_project/aaai2019_changed_0802
# Out:
# /content/deepl_final_project/aaai2019_changed_0802

# %%
#To create 100 scenarios with number of shared entities = 4, 5 and 6 each, run

# !python generate_scenarios.py --num_world_each 100 --min_shared 4 --max_shared 6
# Out:
# 4
# 100% 100/100 [04:01<00:00,  2.41s/it]
# 5
# 100% 100/100 [05:04<00:00,  3.04s/it]
# 6
# 100% 100/100 [06:34<00:00,  3.94s/it]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Comparison of the final selection probabilities based on color and size
#Basic statistics of the dataset 
# Add heatmap 

# !python simple_analysis.py --basic_statistics --count_dict --plot_selection_bias
# Out:
# -- case 4 --
# total dialogs: 2189
# success rate: 0.65829
# average tokens: 63.99543
# average turns: 4.97122
# average tokens per turn: 12.87319
#
# -- case 5 --
# total dialogs: 2279
# success rate: 0.76964
# average tokens: 59.03817
# average turns: 4.77139
# average tokens per turn: 12.37337
#
# -- case 6 --
# total dialogs: 2292
# success rate: 0.86998
# average tokens: 54.10471
# average turns: 4.56108
# average tokens per turn: 11.86225
#
# total dialogues: 6760
# vocabulary size: 3624
# occupancy of top 10% frequent tokens: 0.96938
# approximation: 1283 (3.98324 per 100 utterances)
# subtlety: 3017 (9.36666 per 100 utterances)
# extremity: 3013 (9.35424 per 100 utterances)
# exactness/confidence: 875 (2.71655 per 100 utterances)
# uncertainty: 1869 (5.80255 per 100 utterances)
# <Figure size 640x480 with 2 Axes>

# %%
#Most of experimental scripts are based on Facebook's end-to-end-negotiator.To conform the data to their format, run:
! python transform_to_txt.py --normalize

# %%
#To create additional testsets
! python transform_to_txt.py --normalize --uncorrelated
! python transform_to_txt.py --normalize --success_only

# %% [markdown]
# # **Reproduced Experiments**

# %%
#Change directory 
# %cd /content/deepl_final_project/aaai2019_changed_0802/experiments
# Out:
# /content/onecommon/aaai2019/experiments

# %% [markdown]
# **Context** **Only** **(MLP)**

# %%
# Full testset (10 differenrt seeds)
# result: 30.93 \pm 0.7 
# paper: (31.13 + std 0.6)

# !python train.py \
--context_only \
--test_corpus full
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# | epoch 001 | trainloss 1.930 | s/epoch 1.43 | trainaccuracy 0.202 | lr 0.00100000
# | epoch 001 | validloss 1.897 | validselectppl 6.667
# | epoch 001 | valid_select_accuracy 0.276
# | epoch 002 | trainloss 1.914 | s/epoch 1.42 | trainaccuracy 0.239 | lr 0.00100000
# | epoch 002 | validloss 1.893 | validselectppl 6.637
# | epoch 002 | valid_select_accuracy 0.282
# | epoch 003 | trainloss 1.915 | s/epoch 1.42 | trainaccuracy 0.242 | lr 0.00100000
# | epoch 003 | validloss 1.890 | validselectppl 6.618
# | epoch 003 | valid_select_accuracy 0.285
# | epoch 004 | trainloss 1.913 | s/epoch 1.44 | trainaccuracy 0.245 | lr 0.00100000
# | epoch 004 | validloss 1.897 | validselectppl 6.665
# ...

# %%
#Uncorolated
# result: 30.37 \pm 1.1
# paper: (31.56)  

# !python train.py \
--context_only \
--test_corpus uncorrelated
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_uncorrelated.txt, total 387296, unks 5645, ratio 1.46%
# dataset data/onecommon/valid_uncorrelated.txt, total 41415, unks 692, ratio 1.67%
# dataset data/onecommon/test_uncorrelated.txt, total 40735, unks 630, ratio 1.55%
# | epoch 001 | trainloss 1.929 | s/epoch 1.43 | trainaccuracy 0.203 | lr 0.00100000
# | epoch 001 | validloss 1.902 | validselectppl 6.701
# | epoch 001 | valid_select_accuracy 0.272
# | epoch 002 | trainloss 1.913 | s/epoch 1.45 | trainaccuracy 0.243 | lr 0.00100000
# | epoch 002 | validloss 1.897 | validselectppl 6.664
# | epoch 002 | valid_select_accuracy 0.269
# | epoch 003 | trainloss 1.913 | s/epoch 1.42 | trainaccuracy 0.240 | lr 0.00100000
# ...

# %%
# Success Only
# result: 33.31 \pm 1.1 
# paper: (34.26)

# !python train.py \
--context_only \
--test_corpus success_only
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_success_only.txt, total 282518, unks 3945, ratio 1.40%
# dataset data/onecommon/valid_success_only.txt, total 32085, unks 527, ratio 1.64%
# dataset data/onecommon/test_success_only.txt, total 31012, unks 443, ratio 1.43%
# | epoch 001 | trainloss 1.929 | s/epoch 1.48 | trainaccuracy 0.202 | lr 0.00100000
# | epoch 001 | validloss 1.895 | validselectppl 6.656
# | epoch 001 | valid_select_accuracy 0.282
# | epoch 002 | trainloss 1.915 | s/epoch 1.44 | trainaccuracy 0.237 | lr 0.00100000
# | epoch 002 | validloss 1.894 | validselectppl 6.645
# | epoch 002 | valid_select_accuracy 0.275
# | epoch 003 | trainloss 1.912 | s/epoch 1.44 | trainaccuracy 0.242 | lr 0.00100000
# ...

# %% [markdown]
# **Context Only (RN)**

# %%
# Full testset 
# result: 33.40 \pm 1.1
# paper: 33.46 (std 0.9)

# !python train.py \
--context_only \
--rel_ctx_encoder \
--test_corpus full
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# | epoch 001 | trainloss 1.921 | s/epoch 4.08 | trainaccuracy 0.229 | lr 0.00100000
# | epoch 001 | validloss 1.877 | validselectppl 6.535
# | epoch 001 | valid_select_accuracy 0.304
# | epoch 002 | trainloss 1.887 | s/epoch 3.73 | trainaccuracy 0.267 | lr 0.00100000
# | epoch 002 | validloss 1.843 | validselectppl 6.319
# | epoch 002 | valid_select_accuracy 0.322
# | epoch 003 | trainloss 1.871 | s/epoch 4.35 | trainaccuracy 0.279 | lr 0.00100000
# | epoch 003 | validloss 1.843 | validselectppl 6.317
# | epoch 003 | valid_select_accuracy 0.301
# | epoch 004 | trainloss 1.856 | s/epoch 3.69 | trainaccuracy 0.287 | lr 0.00100000
# | epoch 004 | validloss 1.851 | validselectppl 6.364
# ...

# %%
# Sucess Only testset
# result: 36.52 \pm 1.9
# paper: 35.00

# !python train.py \
--context_only \
--rel_ctx_encoder \
--test_corpus success_only
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_success_only.txt, total 282518, unks 3945, ratio 1.40%
# dataset data/onecommon/valid_success_only.txt, total 32085, unks 527, ratio 1.64%
# dataset data/onecommon/test_success_only.txt, total 31012, unks 443, ratio 1.43%
# | epoch 001 | trainloss 1.919 | s/epoch 4.31 | trainaccuracy 0.224 | lr 0.00100000
# | epoch 001 | validloss 1.891 | validselectppl 6.629
# | epoch 001 | valid_select_accuracy 0.264
# | epoch 002 | trainloss 1.893 | s/epoch 3.68 | trainaccuracy 0.267 | lr 0.00100000
# | epoch 002 | validloss 1.847 | validselectppl 6.339
# | epoch 002 | valid_select_accuracy 0.293
# | epoch 003 | trainloss 1.868 | s/epoch 3.70 | trainaccuracy 0.283 | lr 0.00100000
# ...

# %%
# Uncorrelated testset 
# result: 33.73 \pm 1.2
# paper: 32.44

# !python train.py \
--context_only \
--rel_ctx_encoder \
--test_corpus uncorrelated
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_uncorrelated.txt, total 387296, unks 5645, ratio 1.46%
# dataset data/onecommon/valid_uncorrelated.txt, total 41415, unks 692, ratio 1.67%
# dataset data/onecommon/test_uncorrelated.txt, total 40735, unks 630, ratio 1.55%
# | epoch 001 | trainloss 1.920 | s/epoch 3.66 | trainaccuracy 0.232 | lr 0.00100000
# | epoch 001 | validloss 1.889 | validselectppl 6.614
# | epoch 001 | valid_select_accuracy 0.285
# | epoch 002 | trainloss 1.890 | s/epoch 3.66 | trainaccuracy 0.266 | lr 0.00100000
# | epoch 002 | validloss 1.845 | validselectppl 6.327
# | epoch 002 | valid_select_accuracy 0.290
# | epoch 003 | trainloss 1.867 | s/epoch 3.72 | trainaccuracy 0.280 | lr 0.00100000
# ...

# %% [markdown]
# **Context + Dialgoue (MLP)**

# %%
# Full testset 
# result: 36.18 \pm 2.0
# paper: 35.85 (std 1.6)

# !python train.py \
--test_corpus full
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# | epoch 001 | trainloss 1.933 | s/epoch 3.47 | trainaccuracy 0.197 | lr 0.00100000
# | epoch 001 | validloss 1.900 | validselectppl 6.683
# | epoch 001 | valid_select_accuracy 0.282
# | epoch 002 | trainloss 1.915 | s/epoch 3.16 | trainaccuracy 0.236 | lr 0.00100000
# | epoch 002 | validloss 1.893 | validselectppl 6.637
# | epoch 002 | valid_select_accuracy 0.290
# | epoch 003 | trainloss 1.914 | s/epoch 3.50 | trainaccuracy 0.242 | lr 0.00100000
# | epoch 003 | validloss 1.890 | validselectppl 6.621
# | epoch 003 | valid_select_accuracy 0.279
# | epoch 004 | trainloss 1.908 | s/epoch 3.14 | trainaccuracy 0.242 | lr 0.00100000
# | epoch 004 | validloss 1.899 | validselectppl 6.678
# ...

# %%
# Sucess Only testset
# result: 38.41 \pm 1.5
# paper: 38.89

# !python train.py \
--test_corpus success_only
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_success_only.txt, total 282518, unks 3945, ratio 1.40%
# dataset data/onecommon/valid_success_only.txt, total 32085, unks 527, ratio 1.64%
# dataset data/onecommon/test_success_only.txt, total 31012, unks 443, ratio 1.43%
# | epoch 001 | trainloss 1.930 | s/epoch 3.46 | trainaccuracy 0.199 | lr 0.00100000
# | epoch 001 | validloss 1.902 | validselectppl 6.699
# | epoch 001 | valid_select_accuracy 0.263
# | epoch 002 | trainloss 1.915 | s/epoch 3.15 | trainaccuracy 0.238 | lr 0.00100000
# | epoch 002 | validloss 1.895 | validselectppl 6.650
# | epoch 002 | valid_select_accuracy 0.276
# | epoch 003 | trainloss 1.909 | s/epoch 3.17 | trainaccuracy 0.244 | lr 0.00100000
# ...

# %%
# Uncorrelated testset 
# result: 38.03 \pm 1.7
# paper: 38.07

# !python train.py \
--test_corpus uncorrelated
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_uncorrelated.txt, total 387296, unks 5645, ratio 1.46%
# dataset data/onecommon/valid_uncorrelated.txt, total 41415, unks 692, ratio 1.67%
# dataset data/onecommon/test_uncorrelated.txt, total 40735, unks 630, ratio 1.55%
# | epoch 001 | trainloss 1.931 | s/epoch 3.55 | trainaccuracy 0.201 | lr 0.00100000
# | epoch 001 | validloss 1.905 | validselectppl 6.717
# | epoch 001 | valid_select_accuracy 0.284
# | epoch 002 | trainloss 1.918 | s/epoch 4.74 | trainaccuracy 0.236 | lr 0.00100000
# | epoch 002 | validloss 1.894 | validselectppl 6.646
# | epoch 002 | valid_select_accuracy 0.291
# | epoch 003 | trainloss 1.911 | s/epoch 3.16 | trainaccuracy 0.239 | lr 0.00100000
# ...

# %% [markdown]
# **Context + Dialgoue (RN)**

# %%
# Full testset 
# result: 41.96 \pm 1.1
# paper: 41.50 (std 1.3)

# !python train.py \
--rel_ctx_encoder \
--test_corpus full
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# | epoch 001 | trainloss 1.923 | s/epoch 5.87 | trainaccuracy 0.224 | lr 0.00100000
# | epoch 001 | validloss 1.885 | validselectppl 6.585
# | epoch 001 | valid_select_accuracy 0.287
# | epoch 002 | trainloss 1.890 | s/epoch 5.61 | trainaccuracy 0.266 | lr 0.00100000
# | epoch 002 | validloss 1.854 | validselectppl 6.386
# | epoch 002 | valid_select_accuracy 0.308
# | epoch 003 | trainloss 1.787 | s/epoch 5.63 | trainaccuracy 0.288 | lr 0.00100000
# | epoch 003 | validloss 1.682 | validselectppl 5.377
# | epoch 003 | valid_select_accuracy 0.318
# | epoch 004 | trainloss 1.674 | s/epoch 5.54 | trainaccuracy 0.311 | lr 0.00100000
# | epoch 004 | validloss 1.630 | validselectppl 5.102
# ...

# %%
# Sucess Only testset
# result: 43.50 \pm 1.6  
# paper: 42.22

# !python train.py \
--rel_ctx_encoder \
--test_corpus success_only
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_success_only.txt, total 282518, unks 3945, ratio 1.40%
# dataset data/onecommon/valid_success_only.txt, total 32085, unks 527, ratio 1.64%
# dataset data/onecommon/test_success_only.txt, total 31012, unks 443, ratio 1.43%
# | epoch 001 | trainloss 1.919 | s/epoch 5.76 | trainaccuracy 0.224 | lr 0.00100000
# | epoch 001 | validloss 1.885 | validselectppl 6.589
# | epoch 001 | valid_select_accuracy 0.265
# | epoch 002 | trainloss 1.882 | s/epoch 5.43 | trainaccuracy 0.272 | lr 0.00100000
# | epoch 002 | validloss 1.810 | validselectppl 6.112
# | epoch 002 | valid_select_accuracy 0.293
# | epoch 003 | trainloss 1.746 | s/epoch 5.92 | trainaccuracy 0.298 | lr 0.00100000
# ...

# %%
# Uncorrelated testset 
# result: 40.28 \pm 1.2
# paper: 40.15

# !python train.py \
--rel_ctx_encoder \
--test_corpus uncorrelated
# Out:
# cuda
# running experiments with 10 different seeds
# dataset data/onecommon/train.txt, total 774592, unks 11290, ratio 1.46%
# dataset data/onecommon/valid.txt, total 82830, unks 1384, ratio 1.67%
# dataset data/onecommon/test.txt, total 81470, unks 1260, ratio 1.55%
# dataset data/onecommon/train_uncorrelated.txt, total 387296, unks 5645, ratio 1.46%
# dataset data/onecommon/valid_uncorrelated.txt, total 41415, unks 692, ratio 1.67%
# dataset data/onecommon/test_uncorrelated.txt, total 40735, unks 630, ratio 1.55%
# | epoch 001 | trainloss 1.918 | s/epoch 5.68 | trainaccuracy 0.227 | lr 0.00100000
# | epoch 001 | validloss 1.881 | validselectppl 6.561
# | epoch 001 | valid_select_accuracy 0.289
# | epoch 002 | trainloss 1.886 | s/epoch 5.33 | trainaccuracy 0.270 | lr 0.00100000
# | epoch 002 | validloss 1.836 | validselectppl 6.272
# | epoch 002 | valid_select_accuracy 0.296
# | epoch 003 | trainloss 1.793 | s/epoch 5.37 | trainaccuracy 0.291 | lr 0.00100000
# ...
