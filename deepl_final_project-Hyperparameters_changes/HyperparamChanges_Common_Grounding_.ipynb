# %%
#Clone 
! git clone https://deepl_22_final_project_username:tVyAPPDFRAZFLsWEathG@gitup.uni-potsdam.de/macphail/deepl_final_project.git
# Out:
# Cloning into 'deepl_final_project'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 455 (delta 90), reused 88 (delta 68), pack-reused 339
# Receiving objects: 100% (455/455), 7.92 MiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (314/314), done.

# %%
#Change directory 
# %cd /content/deepl_final_project/aaai2019_changed_0802/experiments
# Out:
# /content/deepl_final_project/aaai2019_changed_0802/experiments

# %% [markdown]
# # **Hyperparameters Changes on Full Corpus**

# %% [markdown]
# # **Learning rate, Batch size and Number of epochs**

# %% [markdown]
# **Context** **Only** **(MLP)**

# %%
# default batch size and smaller learning rate 
# full corpus 
# !python train.py \
--context_only \
--lr 1e-4 \
--max_epoch 200 \
--test_corpus full
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 163 | valid_select_accuracy 0.297
# | epoch 164 | trainloss 1.833 | s/epoch 1.44 | trainaccuracy 0.304 | lr 0.00010000
# | epoch 164 | validloss 1.838 | validselectppl 6.283
# | epoch 164 | valid_select_accuracy 0.296
# | epoch 165 | trainloss 1.832 | s/epoch 1.47 | trainaccuracy 0.301 | lr 0.00010000
# | epoch 165 | validloss 1.837 | validselectppl 6.277
# | epoch 165 | valid_select_accuracy 0.298
# | epoch 166 | trainloss 1.830 | s/epoch 1.44 | trainaccuracy 0.304 | lr 0.00010000
# | epoch 166 | validloss 1.835 | validselectppl 6.266
# | epoch 166 | valid_select_accuracy 0.296
# | epoch 167 | trainloss 1.827 | s/epoch 1.44 | trainaccuracy 0.303 | lr 0.00010000
# | epoch 167 | validloss 1.835 | validselectppl 6.263
# | epoch 167 | valid_select_accuracy 0.298
# | epoch 168 | trainloss 1.827 | s/epoch 1.43 | trainaccuracy 0.303 | lr 0.00010000
# | epoch 168 | validloss 1.835 | validselectppl 6.264
# ...

# %%
# default learning rate and bigger batch size
#Full corpus
# !python train.py \
--context_only \
--bsz 32 \
--max_epoch 200
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 161 | valid_select_accuracy 0.294
# | epoch 162 | trainloss 1.818 | s/epoch 1.44 | trainaccuracy 0.299 | lr 0.00100000
# | epoch 162 | validloss 1.839 | validselectppl 6.288
# | epoch 162 | valid_select_accuracy 0.290
# | epoch 163 | trainloss 1.813 | s/epoch 1.44 | trainaccuracy 0.305 | lr 0.00100000
# | epoch 163 | validloss 1.846 | validselectppl 6.337
# | epoch 163 | valid_select_accuracy 0.295
# | epoch 164 | trainloss 1.810 | s/epoch 1.46 | trainaccuracy 0.303 | lr 0.00100000
# | epoch 164 | validloss 1.837 | validselectppl 6.278
# | epoch 164 | valid_select_accuracy 0.296
# | epoch 165 | trainloss 1.818 | s/epoch 1.43 | trainaccuracy 0.299 | lr 0.00100000
# | epoch 165 | validloss 1.834 | validselectppl 6.259
# | epoch 165 | valid_select_accuracy 0.310
# | epoch 166 | trainloss 1.815 | s/epoch 1.43 | trainaccuracy 0.307 | lr 0.00100000
# | epoch 166 | validloss 1.847 | validselectppl 6.343
# ...

# %%
#training for longer time(more number of epochs)
#full corpus 
# !python train.py \
--context_only \
--max_epoch 200
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 163 | valid_select_accuracy 0.295
# | epoch 164 | trainloss 1.810 | s/epoch 1.35 | trainaccuracy 0.303 | lr 0.00100000
# | epoch 164 | validloss 1.837 | validselectppl 6.278
# | epoch 164 | valid_select_accuracy 0.296
# | epoch 165 | trainloss 1.818 | s/epoch 1.36 | trainaccuracy 0.299 | lr 0.00100000
# | epoch 165 | validloss 1.834 | validselectppl 6.259
# | epoch 165 | valid_select_accuracy 0.310
# | epoch 166 | trainloss 1.815 | s/epoch 1.38 | trainaccuracy 0.307 | lr 0.00100000
# | epoch 166 | validloss 1.847 | validselectppl 6.343
# | epoch 166 | valid_select_accuracy 0.293
# | epoch 167 | trainloss 1.815 | s/epoch 1.39 | trainaccuracy 0.309 | lr 0.00100000
# | epoch 167 | validloss 1.840 | validselectppl 6.294
# | epoch 167 | valid_select_accuracy 0.299
# | epoch 168 | trainloss 1.812 | s/epoch 1.40 | trainaccuracy 0.302 | lr 0.00100000
# | epoch 168 | validloss 1.844 | validselectppl 6.321
# ...

# %% [markdown]
# **Context Only (RN)**

# %%
## Default batch size and samller learning rate 
#full copus 
# !python train.py \
--context_only \
--rel_ctx_encoder \
--lr 0.0001 \
--max_epoch 200
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 163 | valid_select_accuracy 0.321
# | epoch 164 | trainloss 1.614 | s/epoch 5.52 | trainaccuracy 0.399 | lr 0.00010000
# | epoch 164 | validloss 1.843 | validselectppl 6.318
# | epoch 164 | valid_select_accuracy 0.317
# | epoch 165 | trainloss 1.620 | s/epoch 5.48 | trainaccuracy 0.396 | lr 0.00010000
# | epoch 165 | validloss 1.847 | validselectppl 6.339
# | epoch 165 | valid_select_accuracy 0.316
# | epoch 166 | trainloss 1.622 | s/epoch 5.49 | trainaccuracy 0.395 | lr 0.00010000
# | epoch 166 | validloss 1.845 | validselectppl 6.326
# | epoch 166 | valid_select_accuracy 0.319
# | epoch 167 | trainloss 1.614 | s/epoch 5.48 | trainaccuracy 0.397 | lr 0.00010000
# | epoch 167 | validloss 1.850 | validselectppl 6.362
# | epoch 167 | valid_select_accuracy 0.321
# | epoch 168 | trainloss 1.621 | s/epoch 5.49 | trainaccuracy 0.396 | lr 0.00010000
# | epoch 168 | validloss 1.846 | validselectppl 6.336
# ...

# %%
#default learning rate and bigger batch size 
# !python train.py \
--context_only \
--rel_ctx_encoder \
--bsz 32 \
--max_epoch 200
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 163 | valid_select_accuracy 0.323
# | epoch 164 | trainloss 1.411 | s/epoch 1.86 | trainaccuracy 0.487 | lr 0.00100000
# | epoch 164 | validloss 1.890 | validselectppl 6.619
# | epoch 164 | valid_select_accuracy 0.320
# | epoch 165 | trainloss 1.421 | s/epoch 1.86 | trainaccuracy 0.476 | lr 0.00100000
# | epoch 165 | validloss 1.891 | validselectppl 6.625
# | epoch 165 | valid_select_accuracy 0.318
# | epoch 166 | trainloss 1.415 | s/epoch 1.84 | trainaccuracy 0.480 | lr 0.00100000
# | epoch 166 | validloss 1.884 | validselectppl 6.579
# | epoch 166 | valid_select_accuracy 0.320
# | epoch 167 | trainloss 1.415 | s/epoch 1.85 | trainaccuracy 0.483 | lr 0.00100000
# | epoch 167 | validloss 1.876 | validselectppl 6.528
# | epoch 167 | valid_select_accuracy 0.318
# | epoch 168 | trainloss 1.408 | s/epoch 2.39 | trainaccuracy 0.482 | lr 0.00100000
# | epoch 168 | validloss 1.880 | validselectppl 6.554
# ...

# %%
# training for longer time (more epochs)
# !python train.py \
--context_only \
--rel_ctx_encoder \
--max_epoch 200
# Out:
# Streaming output truncated to the last 5000 lines.
# | epoch 163 | valid_select_accuracy 0.340
# | epoch 164 | trainloss 1.408 | s/epoch 3.45 | trainaccuracy 0.487 | lr 0.00100000
# | epoch 164 | validloss 1.887 | validselectppl 6.601
# | epoch 164 | valid_select_accuracy 0.343
# | epoch 165 | trainloss 1.394 | s/epoch 3.45 | trainaccuracy 0.488 | lr 0.00100000
# | epoch 165 | validloss 1.897 | validselectppl 6.664
# | epoch 165 | valid_select_accuracy 0.353
# | epoch 166 | trainloss 1.396 | s/epoch 3.43 | trainaccuracy 0.485 | lr 0.00100000
# | epoch 166 | validloss 1.899 | validselectppl 6.681
# | epoch 166 | valid_select_accuracy 0.338
# | epoch 167 | trainloss 1.390 | s/epoch 3.44 | trainaccuracy 0.493 | lr 0.00100000
# | epoch 167 | validloss 1.904 | validselectppl 6.712
# | epoch 167 | valid_select_accuracy 0.346
# | epoch 168 | trainloss 1.389 | s/epoch 3.48 | trainaccuracy 0.494 | lr 0.00100000
# | epoch 168 | validloss 1.910 | validselectppl 6.756
# ...
